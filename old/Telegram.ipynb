# %%
import requests

BOT_TOKEN = "8767598546:AAHV9B-vaDO73DWSuoex_VGMpFfTDUJ-APE"
CHAT_ID = "-1003658245081"

def send_telegram(message):
    url = f"https://api.telegram.org/bot{BOT_TOKEN}/sendMessage"
    data = {
        "chat_id": CHAT_ID,
        "text": message
    }

    response = requests.post(url, data=data)
    print(response.status_code)
    print(response.text)

send_telegram("TEST🚀")
# Out:
# 200
# {"ok":true,"result":{"message_id":17,"from":{"id":8767598546,"is_bot":true,"first_name":"PL Betting model","username":"BettingModelPL_bot"},"chat":{"id":-1003658245081,"title":"Betting Model","type":"supergroup"},"date":1775239179,"text":"TEST\ud83d\ude80"}}
