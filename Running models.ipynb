# %%
# %run "C:/Users/semwi/FPL-Core-Insights/update/master_update.py"
# Out:
# ══════════════════════════════════════════
#   STAP 1 – ClubElo ratings bijwerken
# ══════════════════════════════════════════
#    📂 59,277 rijen | ophalen vanaf 2026-02-25
#    [01/41] Arsenal            ✅ 15 rijen
#    [02/41] AstonVilla         ✅ 19 rijen
#    [03/41] Bournemouth        ✅ 17 rijen
#    [04/41] Brentford          ✅ 16 rijen
#    [05/41] Brighton           ✅ 19 rijen
#    [06/41] Chelsea            ✅ 18 rijen
#    [07/41] CrystalPalace      ✅ 17 rijen
#    [08/41] Everton            ✅ 16 rijen
#    [09/41] Fulham             ✅ 18 rijen
#    [10/41] Ipswich            ✅ 18 rijen
#    [11/41] Forest             ✅ 23 rijen
#    [12/41] Leeds              ✅ 19 rijen
#    [13/41] Leicester          ✅ 14 rijen
#    [14/41] Liverpool          ✅ 16 rijen
#    [15/41] ManCity            ✅ 15 rijen
#    [16/41] ManUnited          ✅ 17 rijen
#    [17/41] Newcastle          ✅ 15 rijen
#    [18/41] Southampton        ✅ 12 rijen
#    [19/41] Tottenham          ✅ 21 rijen
# ...

# %%
# %run "C:/Users/semwi/FPL-Core-Insights/update/kalman_update-2020-PI.py"
# Out:
# Laden understat_xg.csv...
#   2608 wedstrijden (vanaf 2019/2020)
#   Seizoenen: ['2019/2020', '2020/2021', '2021/2022', '2022/2023', '2023/2024', '2024/2025', '2025/2026']
#
# Lineup strength laden en pivotten...
#   Gekoppeld: 2608/2608 wedstrijden
#
# Lineup strength normalisatie:
#   Ruwe diff  — mean: 0.0004, std: 0.1647
#   Norm bereik: -3.21 tot 3.45
#
# Pi-ratings berekenen (algemeen + context-specifiek)...
#   Algemene rating bereik  : -1.032 tot 1.795
#   Context rating bereik   : -0.888 tot 1.523
#   Context cold-start (home=0): 28 wedstrijden (1.1%) — team had nog niet thuis gespeeld
#
# ...
# KALMAN 1 — xG versie (getuunde asymmetrische parameters)
# ...
#   Wedstrijden met xG: 2608
#   Opgeslagen: C:\Users\semwi\FPL-Core-Insights\data\Kalman data\kalman_expected_goals.csv  (2,608 rijen)

# %%
# %run "C:/Users/semwi/FPL-Core-Insights/update/xgboost_update.py"
# Out:
# Match raw: (3598, 111)
# Elo:       (59277, 8)
#
# Elo ratings koppelen aan wedstrijden...
# Elo gekoppeld: 3598 / 3598 wedstrijden
#
# Pi ratings berekenen op match_data...
# Pi ratings berekend voor 3598 wedstrijden
#
# Top 5 sterkste teams (Pi home rating):
#   Arsenal: 1.6681
#   Manchester City: 1.5215
#   Liverpool: 0.9827
#   Chelsea: 0.9043
#   Manchester United: 0.8645
#
# Pi kolommen:  ['home_pi_home_pre', 'away_pi_away_pre', 'pi_expected_gd_pre', 'pi_diff']
# Elo kolommen: ['home_elo', 'away_elo', 'elo_diff']
#
# Pi matched:  3598 / 3598
# Elo matched: 3598 / 3598
#
# Klaar! match_data.csv bijgewerkt
# Finale shape: (3598, 118)
# Draai nu xgboost_update.py om training_data_with_rolling.csv opnieuw te bouwen.

# %%
# %run "C:/Users/semwi/FPL-Core-Insights/update/xgboost_update-Copy1.py"
# Out:
# Laden...
#   match_data:      3598 rijen (3527 gespeeld)
#   understat_xg:    4508 rijen
#   player_strength: 3597 rijen
#   Stat kolommen:   32
# xG koppelen...
#   xG gevuld: 2865/3539
# Rolling berekenen...
#   Leakage check: OK - alle teams starten met NaN
# Koppelen...
#   71 aankomende wedstrijden gevuld
#   Kolommen verwijderd (>50% leeg): 156 (van 486 naar 330)
#
# Klaar! C:\Users\semwi\FPL-Core-Insights\data\XGboost data\training_data_with_rolling.csv
#   Rijen:    3,634
#   Kolommen: 330
#
# Sanity check Liverpool (eerste 4 wedstrijden):
#           timestamp         home_team      away_team  home_goals_for_alltime_overall  home_goals_for_last5_overall  home_goals_for_alltime_home
# 2016-08-14 15:00:00           Arsenal      Liverpool                             NaN                           NaN                          NaN
# 2016-08-20 14:00:00           Burnley      Liverpool                           0.000                         0.000                          0.0
# ...
