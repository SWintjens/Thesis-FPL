# %%
# %run "C:/Users/semwi/FPL-Core-Insights_Thesis/update/master_update.py"
# Out:
# ══════════════════════════════════════════
#   STAP 1 – Sofascore gespeelde wedstrijden
# ══════════════════════════════════════════
#    📂 Bekende wedstrijden: 383
#    📊 Sofascore geeft 360 wedstrijden
#    🆕 Nieuw: 0 | 🔄 Overschrijven: 10
#    [01/10] 🔄 GW36 – 14024024... ✅ Liverpool FC 1-1 Chelsea | 40 spelers
#    [02/10] 🔄 GW36 – 14023948... ✅ Fulham 0-1 Bournemouth | 40 spelers
#    [03/10] 🔄 GW36 – 14023935... ✅ Brighton & Hove Albion 3-0 Wolverhampton | 40 spelers
#    [04/10] 🔄 GW36 – 14023938... ✅ Sunderland 0-0 Manchester United | 40 spelers
#    [05/10] 🔄 GW36 – 14023946... ✅ Manchester City 3-0 Brentford | 40 spelers
#    [06/10] 🔄 GW36 – 14023937... ✅ Crystal Palace 2-2 Everton | 40 spelers
#    [07/10] 🔄 GW36 – 14023929... ✅ Burnley 2-2 Aston Villa | 40 spelers
#    [08/10] 🔄 GW36 – 14023943... ✅ Nottingham Forest 1-1 Newcastle United | 40 spelers
#    [09/10] 🔄 GW36 – 14023942... ✅ West Ham United 0-1 Arsenal | 40 spelers
# ...

# %%
# %run "C:/Users/semwi/FPL-Core-Insights_Thesis/update/kalman_update-2020-PI.py"
# Out:
# Laden understat_xg.csv...
#   3779 wedstrijden (vanaf 2016/2017)
# Lineup strength laden...
# Pi-ratings berekenen...
#   Wedstrijden met xG: 3779
#
# ...
# EKF variant: basis
# ...
#   Opgeslagen: C:\Users\semwi\FPL-Core-Insights_Thesis\data\kalman_basis.csv  (3,779 rijen)
#
# ...
# EKF variant: asymmetrie
# ...
#   Opgeslagen: C:\Users\semwi\FPL-Core-Insights_Thesis\data\kalman_asymmetrie.csv  (3,779 rijen)
#
# ...
# EKF variant: asymmetrie + lineup
# ...
#   Opgeslagen: C:\Users\semwi\FPL-Core-Insights_Thesis\data\kalman_asymmetrie_lineup.csv  (3,779 rijen)
#
# Klaar. Drie CSV's aangemaakt:
#   → kalman_basis.csv
#   → kalman_asymmetrie.csv
#   → kalman_asymmetrie_lineup.csv
